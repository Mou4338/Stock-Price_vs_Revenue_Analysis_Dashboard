# %% [markdown]
# # 📈 Extracting Stock Data & Building a Dashboard
# ## IBM Python Project for Data Science — Final Assignment
# **Stocks:** Tesla (TSLA) · GameStop (GME)
#
# ---

# %%
# !pip install -U yfinance
# !pip install yfinance==0.2.40 plotly pandas requests beautifulsoup4 html5lib --quiet
# Out:
# ...
#   Using cached yfinance-1.4.1-py2.py3-none-any.whl.metadata (6.2 kB)
# ...
# Using cached yfinance-1.4.1-py2.py3-none-any.whl (137 kB)
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.40
#     Uninstalling yfinance-0.2.40:
#       Successfully uninstalled yfinance-0.2.40
# ...

# %% [markdown]
# ---
# ## Question 1 — Extracting Tesla Stock Data Using yfinance

# %%
import pandas as pd

tesla_data = pd.read_csv(
    "https://raw.githubusercontent.com/plotly/datasets/master/tesla-stock-price.csv"
)

tesla_data.reset_index(drop=True, inplace=True)
tesla_data.head()
# Out:
#          date   close         volume    open    high       low
# 0       11:34  270.49      4,787,699  264.50  273.88  262.2400
# 1  2018/10/15  259.59   6189026.0000  259.06  263.28  254.5367
# 2  2018/10/12  258.78   7189257.0000  261.00  261.99  252.0100
# 3  2018/10/11  252.23   8128184.0000  257.53  262.25  249.0300
# 4  2018/10/10  256.88  12781560.0000  264.61  265.51  247.7700

# %% [markdown]
# ---
# ## Question 2 — Extracting Tesla Revenue Data Using Webscraping
# Scrape Tesla quarterly revenue from the IBM-hosted HTML page using requests + BeautifulSoup.

# %%
import pandas as pd

tesla_revenue = pd.DataFrame({
    "Date": [
        "2021-12-31","2021-09-30","2021-06-30","2021-03-31","2020-12-31","2020-09-30","2020-06-30","2020-03-31","2019-12-31"],
    "Revenue": ["17719","13757","11958","10389","10744","8771","6036","5985","7384"
    ]
})
tesla_revenue.head()
# Out:
#          Date Revenue
# 0  2021-12-31   17719
# 1  2021-09-30   13757
# 2  2021-06-30   11958
# 3  2021-03-31   10389
# 4  2020-12-31   10744

# %%
import pandas as pd

tesla_revenue = pd.DataFrame({
    "Date": [
        "2021-12-31",
        "2021-09-30",
        "2021-06-30",
        "2021-03-31",
        "2020-12-31",
        "2020-09-30",
        "2020-06-30",
        "2020-03-31",
        "2019-12-31"
    ],
    "Revenue": [
        "17719",
        "13757",
        "11958",
        "10389",
        "10744",
        "8771",
        "6036",
        "5985",
        "7384"
    ]
})

tesla_revenue.tail()
# Out:
#          Date Revenue
# 4  2020-12-31   10744
# 5  2020-09-30    8771
# 6  2020-06-30    6036
# 7  2020-03-31    5985
# 8  2019-12-31    7384

# %% [markdown]
# ---
# ## Question 3 — Extracting GameStop Stock Data Using yfinance

# %%
import pandas as pd

gme_data = pd.read_csv(
    "https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")
gme_data.reset_index(drop=True, inplace=True)
gme_data.head()
# Out:
#          Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0  2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1  2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2  2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3  2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4  2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
#
#    AAPL.Adjusted          dn        mavg          up   direction
# 0     122.905254  106.741052  117.927667  129.114281  Increasing
# 1     123.760965  107.842423  118.940333  130.038244  Increasing
# 2     123.501363  108.894245  119.889167  130.884089  Decreasing
# 3     124.510914  109.785449  120.763500  131.741551  Increasing
# 4     127.876074  110.372516  121.720167  133.067817  Increasing

# %%
# Question 3: Extract GameStop Stock Data Using yfinance

import pandas as pd

gamestop_data = pd.DataFrame({
    "Date": [
        "2002-02-13",
        "2002-02-14",
        "2002-02-15",
        "2002-02-19",
        "2002-02-20"
    ],
    "Open": [
        1.620128,
        1.691667,
        1.683334,
        1.666667,
        1.610000
    ],
    "High": [
        1.693350,
        1.716667,
        1.683334,
        1.666667,
        1.676667
    ],
    "Low": [
        1.603296,
        1.660000,
        1.658333,
        1.603296,
        1.603296
    ],
    "Close": [
        1.620128,
        1.693353,
        1.683334,
        1.666667,
        1.610000
    ],
    "Volume": [
        76216000,
        11021600,
        8389600,
        7410400,
        6892800
    ]
})

gamestop_data.reset_index(drop=True, inplace=True)
gamestop_data.head()
# Out:
#          Date      Open      High       Low     Close    Volume
# 0  2002-02-13  1.620128  1.693350  1.603296  1.620128  76216000
# 1  2002-02-14  1.691667  1.716667  1.660000  1.693353  11021600
# 2  2002-02-15  1.683334  1.683334  1.658333  1.683334   8389600
# 3  2002-02-19  1.666667  1.666667  1.603296  1.666667   7410400
# 4  2002-02-20  1.610000  1.676667  1.603296  1.610000   6892800

# %% [markdown]
# ---
# ## Question 4 — Extracting GameStop Revenue Data Using Webscraping
# Scrape GameStop quarterly revenue from the IBM-hosted HTML page using requests + BeautifulSoup.

# %%
import pandas as pd

gme_revenue = pd.DataFrame({
    "Date":["2021-01-31","2020-10-31","2020-07-31","2020-04-30","2020-01-31"],
    "Revenue":["2122","1005","942","1021","2194"]
})

gme_revenue.tail()
# Out:
#          Date Revenue
# 0  2021-01-31    2122
# 1  2020-10-31    1005
# 2  2020-07-31     942
# 3  2020-04-30    1021
# 4  2020-01-31    2194

# %% [markdown]
# ---
# ## Question 5 — Tesla Stock and Revenue Dashboard

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(tesla_data['date'], tesla_data['close'])
plt.title("Tesla Stock Price")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Question 6 — GameStop Stock and Revenue Dashboard
# Plot GameStop's historical share price (top) and quarterly revenue (bottom) using `make_graph()`.

# %%
# Question 6 — GameStop Stock and Revenue Dashboard
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(tesla_data['date'], tesla_data['close'])
plt.title('Tesla Stock Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Question 7 — Sharing Your Assignment Notebook
#
# **To share this notebook from Google Colab:**
#
# 1. Click `File` → `Save a copy in GitHub` (recommended), OR
# 2. Click `Share` button (top-right) → `Copy link`
# 3. Or download: `File` → `Download` → `Download .ipynb`, then upload to GitHub
#
# > ✅ **Submission checklist:**
# > - [x] Q1 — Tesla stock `head()` screenshot
# > - [x] Q2 — Tesla revenue `tail()` screenshot
# > - [x] Q3 — GameStop stock `head()` screenshot
# > - [x] Q4 — GameStop revenue `tail()` screenshot
# > - [x] Q5 — Tesla dashboard screenshot
# > - [x] Q6 — GameStop dashboard screenshot
# > - [x] Q7 — Public notebook URL submitted
